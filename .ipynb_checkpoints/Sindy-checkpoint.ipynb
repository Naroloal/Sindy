# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
Neurons = '/home/lorenzo/Principal/Doctorado/Noise-Neuron discriminator/Datos/Neuron_P303132_embedded'
Neurons = pd.read_pickle(Neurons)

# %%
Neurons = df[df.bNoise == 0]
Neurons.reset_index(inplace = True)

# %%
df_list = Neurons['Mean'].apply(pd.Series).T
df_sorted = df_list.sort_values(19)
df_sorted[19]
g1 = [19,20,18,21,17,22]
g2 = [23,16,24,25,26,15,27]
g3 = [28,29,30,14,31,32,33]
g4 = [34,13,35,36,37,38]

# %%
df_list.plot(legend = False)

# %%
g0 = [19]
g1 = [19,20,18,21,17,22]
g2 = [23,16,24,25,26,15,27]
g3 = [28,29,30,14,31,32,33]
g4 = [34,13,35,36,37,38]
gs = np.array([g0,g1,g2,g3,g4])
dfs = {i:pd.DataFrame.from_records(Neurons.embedding.loc[g].to_list(),columns= ['x','y','z']) for i,g in enumerate(gs)}

# %% [raw]
# V = neuron.Mean
# Vr = np.roll(V,1)

# %%
dvdt = (Vr-V)

# %%
theta = np.zeros([len(V),7])
theta[:,0] = np.ones_like(V)
theta[:,1] = V
theta[:,2] = V**2
theta[:,3] = V**3
theta[:,4] = V**4
theta[:,5] = np.sin(V)
theta[:,6] = np.sin(V**2)

# %%
theta = np.zeros([len(V),6])
theta.shape
# Out:
# (64, 6)

# %%
print('ajuste de V\n')
clf=linear_model.Lasso(alpha=0.1,max_iter=100000,fit_intercept=False,normalize=False)
clf.fit(-theta,dvdt)
print(clf.coef_)
print(clf.intercept_)
print('\n')
# Out:
# ajuste de V
#
# [0. 0. 0. 0. 0. 0.]
# 0.0
